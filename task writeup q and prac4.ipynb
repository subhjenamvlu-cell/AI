# %%
# Probability of having disease
P_D = 0.01
# Probability of positive test if disease exists
P_Pos_D = 0.99
# Probability of positive test if disease does not exist
P_Pos_NotD = 0.05
# Probability of not having disease
P_NotD = 1 - P_D
# Bayes Rule
P_D_Pos = (P_Pos_D * P_D) / ((P_Pos_D * P_D) + (P_Pos_NotD * P_NotD))
print("Probability that person actually has disease:")
print(round(P_D_Pos * 100, 2), "%")
# Out:
# Probability that person actually has disease:
# 16.67 %

# %% [markdown]
# writeup question

# %%
#Given probabilities
P_Python = 0.20
P_Java = 0.80

P_Placed_Python = 0.90
P_Placed_Java = 0.40

# Total probability of placement
P_Placed = (P_Placed_Python * P_Python) + (P_Placed_Java * P_Java)

# Bayes theorem
P_Python_Placed = (P_Placed_Python * P_Python) / P_Placed

print("subhashree jena T007")
print("Probability student knows Python:", P_Python)
print("Probability student knows Java:", P_Java)
print("Probability that a placed student knows Python:", round(P_Python_Placed, 2))
# Out:
# subhashree jena T007
# Probability student knows Python: 0.2
# Probability student knows Java: 0.8
# Probability that a placed student knows Python: 0.36

# %%
# Given probabilities
P_Blue = 0.15
P_Green = 0.85

P_SaysBlue_given_Blue = 0.80
P_SaysBlue_given_Green = 0.20

# Total probability
P_SaysBlue = (P_SaysBlue_given_Blue * P_Blue) + (P_SaysBlue_given_Green * P_Green)

# Bayes theorem
P_Blue_given_SaysBlue = (P_SaysBlue_given_Blue * P_Blue) / P_SaysBlue

print("subhashree jena T007")
print("Probability taxi was actually Blue:", round(P_Blue_given_SaysBlue, 3))
# Out:
# subhashree jena T007
# Probability taxi was actually Blue: 0.414
